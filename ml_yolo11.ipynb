# %%
import os

# Tạo thư mục 
os.makedirs("/kaggle/working/dataset", exist_ok=True)

#Viết data.yaml
data_yaml = """
train: /kaggle/input/dataset-leaf-2/dataset_split_leaf/images/train
val: /kaggle/input/dataset-leaf-2/dataset_split_leaf/images/val

nc: 1
names: ['leaf']
"""

with open("/kaggle/working/dataset/data.yaml", "w") as f:
    f.write(data_yaml)

# %%
# !pip install ultralytics
from ultralytics import YOLO

# Tải mô hình YOLOv11n-seg huấn luyện sẵn
model = YOLO('yolo11n-seg.pt')
results = model.train(
    data='/kaggle/working/dataset/data.yaml',
    epochs=100,
    imgsz=640
)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.2 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
results = model.predict(source='/kaggle/input/dataset-leaf-2/dataset_split_leaf/images/test/1.X11.2.4.200.26022025.jpg', save=True)
# Out:
# image 1/1 /kaggle/input/dataset-leaf-2/dataset_split_leaf/images/test/1.X11.2.4.200.26022025.jpg: 640x480 38 leafs, 52.0ms
# Speed: 2.6ms preprocess, 52.0ms inference, 14.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/train2

# %%
import shutil

# Copy file best.pt
shutil.copy("runs/segment/train/weights/best.pt", "/kaggle/working/yolo11_leaf_seg.pt")
# Out:
# '/kaggle/working/yolo11_leaf_seg.pt'
