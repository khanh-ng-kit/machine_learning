# %% [markdown]
# + Code dưới đây là phần code nhận diện chữ số viết tay của bộ dữ liệu kinh điển MNIST
# + Nhiệm vụ của các bạn sau khi thực hành là thực hiện code mạng MLP đơn giản sử dụng bộ dữ liệu MNIST để tính tổng của 2 chữ số viết tay . Đầu vào là cặp 2 ảnh chữ số viết tay kích thước 56x28. Đầu ra là tổng 2 số.

# %%
from torchvision import datasets # MNIST datasets
from torchvision.transforms import ToTensor # transform PIL image to torch.Tensor
from torch import nn # neural network library
import torch.nn.functional as F
import torch
from torch.utils.data import DataLoader,random_split # mini-batch loader

import matplotlib.pyplot as plt # print image

# %%
# training set
train_ds = datasets.MNIST('./data', train=True, download=True, transform=ToTensor())
full_train_ds = train_ds
train_size = int(0.8 * len(full_train_ds))
valid_size = len(full_train_ds) - train_size
train_ds, valid_ds = random_split(full_train_ds, [train_size, valid_size])

train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2)
valid_dataloader = DataLoader(valid_ds, batch_size=batch_size, shuffle=False, num_workers=2)

# test set
test_ds = datasets.MNIST('./data', train=False, download=True, transform=ToTensor())

print(f"train {len(train_ds)} test {len(test_ds)}")
# Out:
# train 48000 test 10000

# %%
# the first training sample
x, y = train_ds[0]
print("input type", type(x))
print("input size", x.shape)
print("output type", type(y))
print("target", y)
# Out:
# input type <class 'torch.Tensor'>
# input size torch.Size([1, 28, 28])
# output type <class 'int'>
# target 6

# %%
# plot a grid of samples with targets
def plot_grid(ds, n):
  ncols = 8
  nrows = n // ncols + 1
  plt.subplots(nrows, ncols, figsize=(20, 10))
  for i, (x, y) in enumerate(ds):
    plt.subplot(nrows, ncols, i+1)
    plt.imshow(x[0], cmap="gray")
    plt.title(f'y={y:01d}')
    if i >= n:
      break

plot_grid(train_ds, 10)

# %% [markdown]
# #**Multi-layer Perception (MLP)**

# %%
# define a multi-layer perceptrons
class MLP(nn.Module):
    def __init__(self, batch_size):
        super().__init__()

        # first layer 784 --> 100, relu activation
        self.fc1 = nn.Linear(28*28, 100, bias=False)
        self.relu1 = nn.ReLU()
        # second layer 100 --> 50, relu activation
        self.fc2 = nn.Linear(100, 50, bias=False)
        # Dropout layer + Batchnorm
        self.dropout = nn.Dropout(p=0.2)
        self.batchnorm = nn.BatchNorm1d(50)
        self.relu2 = nn.ReLU()

        # output layer 50 --> 10 class, linear activation
        self.fc3 = nn.Linear(50, 10, bias=False)
        #self.softmax = nn.Softmax(dim=1)


    def forward(self, x):
        x = x.view(batch_size, 28*28) # change (batchsize, 1, 28, 28) into (batchsize, 28*28) to apply linear fc1
        # first layer
        out = self.fc1(x)
        out = self.relu1(out)
        # second layer
        out = self.fc2(out)

        # dropout and batchnorm
        out = self.dropout(out)
        out = self.batchnorm(out)

        out = self.relu2(out)

        # output layer (10-class)
        out = self.fc3(out)

        return out

# %%
# user DataLoader to create mini-batch
batch_size = 16

# training dataloader (with shuffling)
train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2)

# test dataloader (no shuffling)
test_dataloader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=2)

# Checking the dataset
for images, labels in train_dataloader:
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([16, 1, 28, 28])
# Image label dimensions: torch.Size([16])

# %%
# test model with inputs
model = MLP(batch_size=batch_size) # MLP

# define cross entropy loss
loss_func = nn.CrossEntropyLoss()

# use Stochastic Gradient Descent optimizer
arr_lr = [0.1, 0.01, 0.001]
lr = arr_lr[1] # change learning_rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
# change epoch
n_epoch = 10

print(f'Number of epoch: {n_epoch}\nLearning rate: {lr} -- Batch size: {batch_size}')
model.cuda()
for epoch in range(n_epoch):

    # training phase
    model.train()
    print(f"epoch {epoch} started")
    for x, y in train_dataloader:
        # compute output of the model on the mini-batch
        x = x.cuda()
        out = model(x)

        # compute loss function
        loss = loss_func(out, y.cuda())

        # calculate derivative and do a gradient descent step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # evaluate phase
    model.eval()
    total = valid_size
    total_correct = 0 # count number of correct predictions on test set

    for x, y in valid_dataloader:
        with torch.no_grad(): # prevent gradient computation
            x = x.cuda()
            out = model(x)
            # take the maximum output
            pred = torch.argmax(out, dim=1)
            # count the correct predictions
            corrects = (pred == y.cuda()).sum().item()
            total_correct += corrects

    # compute test accuracy for this epoch
    accuracy = total_correct / total
    print(f"epoch {epoch} accuracy {accuracy*100:.2f}%")
# Out:
# Number of epoch: 10
# Learning rate: 0.01 -- Batch size: 16
# epoch 0 started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 29
#      26 total = valid_size
#      27 total_correct = 0 # count number of correct predictions on test set
# ---> 29 for x, y in valid_dataloader:
#      30     with torch.no_grad(): # prevent gradient computation
#      31         x = x.cuda()
#
# File f:\tailieu\HỌC_MÁY\hocmay\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File f:\tailieu\HỌC_MÁY\hocmay\Lib\site-packages\torch\utils\data\dataloader.py:1491, in _MultiProcessingDataLoaderIter._next_data(self)
#    1488     return self._process_data(data, worker_id)
#    1490 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1491 idx, data = self._get_data()
#    1492 self._tasks_outstanding -= 1
#    1493 if self._dataset_kind == _DatasetKind.Iterable:
#    1494     # Check for _IterableDatasetStopIteration
#
# File f:\tailieu\HỌC_MÁY\hocmay\Lib\site-packages\torch\utils\data\dataloader.py:1453, in _MultiProcessingDataLoaderIter._get_data(self)
#    1449     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1450     # need to call `.task_done()` because we don't use `.join()`.
#    1451 else:
#    1452     while True:
# -> 1453         success, data = self._try_get_data()
#    1454         if success:
#    1455             return data
#
# File f:\tailieu\HỌC_MÁY\hocmay\Lib\site-packages\torch\utils\data\dataloader.py:1284, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1271 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1272     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1273     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1281     # Returns a 2-tuple:
#    1282     #   (bool: whether successfully get data, any: data if successful else None)
#    1283     try:
# -> 1284         data = self._data_queue.get(timeout=timeout)
#    1285         return (True, data)
#    1286     except Exception as e:
#    1287         # At timeout and error, we manually check whether any worker has
#    1288         # failed. Note that this is the only mechanism for Windows to detect
#    1289         # worker failures.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\connection.py:346, in PipeConnection._poll(self, timeout)
#     343 if (self._got_empty_message or
#     344             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     345     return True
# --> 346 return bool(wait([self], timeout))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\connection.py:1084, in wait(object_list, timeout)
#    1081                 ready_objects.add(o)
#    1082                 timeout = 0
# -> 1084     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#    1085 finally:
#    1086     # request that overlapped reads stop
#    1087     for ov in ov_list:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\connection.py:1016, in _exhaustive_wait(handles, timeout)
#    1014 ready = []
#    1015 while L:
# -> 1016     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#    1017     if res == WAIT_TIMEOUT:
#    1018         break
#
# KeyboardInterrupt:

# %%
# # calculate prediction on test set
ypred = []
targets = []
model.eval()
with torch.no_grad():
    for x, y in test_dataloader:

        # this is the code to do inference
    #     x = x.view(len(x), -1).cuda()
        x = x.unsqueeze(0).cuda() # append batch size
        out = model(x)
        pred = torch.argmax(out, dim=1)

        # append the prediction results
        ypred.append(pred.cuda())
        targets.append(y.cuda())

n_incorrect = sum([x != y for x, y in zip(targets, ypred)])
print("n_INCORRECT", n_incorrect)
# Out:
# n_INCORRECT tensor([24, 21,  9, 13, 12, 11, 16, 11, 13, 11, 14, 12, 10, 16,  9, 17],
#        device='cuda:0')

# %% [markdown]
# #**Convolutional Neural Network**

# %% [markdown]
# ![image](https://i0.wp.com/syncedreview.com/wp-content/uploads/2017/05/13.png?resize=330%2C230&ssl=1)

# %%
# Conv2d pytorch https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
conv = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1)
# conv = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=1, stride=1, padding=0)
# conv_3 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1, padding=2)
x = torch.rand(1,3,28,28)
out = conv(x)
out.shape
# Out:
# torch.Size([1, 32, 28, 28])

# %% [markdown]
# ![picture](https://drive.google.com/uc?id=1Jz1tllPTE9y4klj7zlMA0TwlAz6jAMYN)

# %%
class CNN_Basic(nn.Module):
    def __init__(self):
        super(CNN_Basic, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1, 1)
        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv2d(32, 64, 3, 1, 1)
        self.relu2 = nn.ReLU()

        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)

        self.fc1 = nn.Linear(3136, 128)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.max_pool2d(x, 2)
        x = self.relu1(x)

        x = self.conv2(x)
        x = F.max_pool2d(x, 2)
        x = self.relu2(x)
        x = self.dropout1(x)

        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.relu3(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        return x

# %%
# test model with inputs
model = CNN_Basic() # MLP

# model = resnet18(num_classes=10, grayscale=True) # resnet

# define cross entropy loss
loss_func = nn.CrossEntropyLoss()

# use Stochastic Gradient Descent optimizer
arr_lr = [0.1, 0.01, 0.001]
lr = arr_lr[1] # change learning_rate
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
# change epoch
n_epoch = 2

print(f'Number of epoch: {n_epoch}\nLearning rate: {lr} -- Batch size: {batch_size}')
model.cuda()
for epoch in range(n_epoch):

    # training phase
    model.train()
    print(f"epoch {epoch} started")
    for x, y in train_dataloader:
        # compute output of the model on the mini-batch
        x = x.cuda()
        out = model(x)

        # compute loss function
        loss = loss_func(out, y.cuda())

        # calculate derivative and do a gradient descent step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # testing phase
    model.eval()
    total = len(test_ds)
    total_correct = 0 # count number of correct predictions on test set

    for x, y in test_dataloader:
        with torch.no_grad(): # prevent gradient computation
            x = x.cuda()
            out = model(x)
            # take the maximum output
            pred = torch.argmax(out, dim=1)
            # count the correct predictions
            corrects = (pred == y.cuda()).sum().item()
            total_correct += corrects

    # compute test accuracy for this epoch
    accuracy = total_correct / total
    print(f"epoch {epoch} accuracy {accuracy*100:.2f}%")
# Out:
# Number of epoch: 2
# Learning rate: 0.01 -- Batch size: 16
# epoch 0 started
# epoch 0 accuracy 98.17%
# epoch 1 started
# epoch 1 accuracy 98.57%
